# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulToronto/Howard-University-Coursera-Linear-Algebra-For-Data-Science-Specialization/blob/main/1_1_2_Modeling_Data_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.1.2 Modeling Data in Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Styles and Palettes

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.palettes.color_palette('coolwarm')
# Out:
# [(0.4044212904941176, 0.5346434904470588, 0.9320019126352941),
#  (0.603162067917647, 0.7315274773529412, 0.9995652785372549),
#  (0.7867207013568628, 0.8448072103686275, 0.9398103849490196),
#  (0.9306685963333333, 0.818876999654902, 0.7591463906980392),
#  (0.9673165156666667, 0.6574708288078431, 0.5381601507294118),
#  (0.8846434386941177, 0.41001709788235297, 0.32250654924705885)]

# %%
sns.palettes.color_palette('winter')
# Out:
# [(0.0, 0.1411764705882353, 0.9294117647058824),
#  (0.0, 0.28627450980392155, 0.8568627450980393),
#  (0.0, 0.42745098039215684, 0.7862745098039216),
#  (0.0, 0.5725490196078431, 0.7137254901960784),
#  (0.0, 0.7137254901960784, 0.6431372549019607),
#  (0.0, 0.8588235294117647, 0.5705882352941176)]

# %%
plt.style.use('seaborn-v0_8-notebook')

# %% [markdown]
# ## 1.1.2.1 Using Graphs in Python to Model Data

# %% [markdown]
# ### Titanic Data

# %%
path = 'https://raw.githubusercontent.com/PaulToronto/'
path += 'Howard-University-Coursera-Linear_Algebra-For-Data-Science-Specialization/'
path += 'main/data/titanic/train.csv'

titanic = pd.read_csv(path)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### titanic.drop()

# %%
titanic.drop('PassengerId', axis=1, inplace=True)

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### `sns.heatmap()`

# %%
plt.figure(figsize=(9, 6))
# no labels on y-axis and no color bar
sns.heatmap(titanic.isnull(), yticklabels=False, cbar=False, cmap='viridis');

# %% [markdown]
# ### titanic.info()

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %% [markdown]
# ### `sns.countplot()`

# %%
sns.countplot(x='Survived', data=titanic, palette='coolwarm');

# %%
sns.countplot(x='Survived', hue='Sex', data=titanic, palette='coolwarm');

# %%
sns.countplot(x='Sex', hue='Survived', data=titanic, palette='coolwarm');

# %%
sns.countplot(x='Survived', hue='Pclass', data=titanic, palette='winter');

# %%
sns.countplot(x='Pclass', hue='Survived', data=titanic, palette='winter');

# %% [markdown]
# ## 1.1.2.2 Doing More with Graphs to Model Data: Part 1

# %% [markdown]
# ### Advantages of [Matplotlib](https://matplotlib.org/)
#
# - Easy to get started for simple plots
# - Support for custom labels and text
# - Great control of every element in the figure
# - High-quality output in many formats
# - Very customizable

# %% [markdown]
# ### Basic Example

# %%
x = np.linspace(-3, 3, 21)
y = x**2
x
# Out:
# array([-3. , -2.7, -2.4, -2.1, -1.8, -1.5, -1.2, -0.9, -0.6, -0.3,  0. ,
#         0.3,  0.6,  0.9,  1.2,  1.5,  1.8,  2.1,  2.4,  2.7,  3. ])

# %%
len(x)
# Out:
# 21

# %%
plt.plot(x, y, 'g-*')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('Basic Plot');

# %% [markdown]
# ### Multiple Plots on Same Canvas

# %%
# (number_rows, number_columns, index)
# the index starts at 1

plt.subplot(2, 2, 1)
plt.plot(x, x**2, 'g')
plt.title('$f(x) = x^{2}$')

plt.subplot(2, 2, 2)
plt.plot(x, x**3, 'r--')
plt.title('$f(x) = x^{3}$');

plt.subplot(2, 2, 3)
plt.plot(x, x**2, 'b')
plt.title('$f(x) = x^{2}$')

plt.subplot(2, 2, 4)
plt.plot(x, x**3, 'm-*')
plt.title('$f(x) = x^{3}$');

plt.tight_layout(); # ensures everything fits

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
#
# ### Markers
#
# - '.' : point marker
# - ',' : pixel marker
# - 'o' : circle marker
# - 'v' : triangle_down marker
# - '^' : triangle_up marker
# - '<' : triangle_left marker
# - '>' : triangle_right marker
# - '1' : tri_down marker
# - '2' : tri_up marker
# - '3' : tri_left marker
# - '4' : tri_right marker
# - '8' : octagon marker
# - 's' : square marker
# - 'p' : pentagon marker
# - 'P' : plus (filled) marker
# - '*' : star marker
# - 'h' : hexagon1 marker
# - 'H' : hexagon2 marker
# - '+' : plus marker
# - 'x' : x marker
# - 'X' : x (filled) marker
# - 'D' : diamond marker
# - 'd' : thin_diamond marker
# - '|' : vline marker
# - '_' : hline marker

# %% [markdown]
# ### Line Styles
#
# - '-' : solid line style
# - '--' : dashed line style
# - '-.' : dash-dot line style
# - ':' : dotted line style

# %% [markdown]
# ### Colors
#
# - 'b' : blue.
# - 'g' : green.
# - 'r' : red.
# - 'c' : cyan.
# - 'm' : magenta.
# - 'y' : yellow.
# - 'k' : black.
# - 'w' : white.

# %% [markdown]
# ### Introduction to the Object Oriented Method
#
# - The dimensions [left, bottom, width, height] of the new axes. All quantities are in fractions of figure width and height.

# %%
fig = plt.figure(figsize=(5, 4))
# rectangle [left, bottom, width, height]
# this makes more sense after looking at next example
axes = fig.add_axes([0.1, 0.1, 0.9, 0.9])
axes.plot(x, y, 'b*');

# %%
fig = plt.figure(figsize=(5, 4))

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes1.plot(x, y, 'b-o', lw=2)
axes1.set_title('Larger Graph')

axes2 = fig.add_axes([0.2, 0.1, 0.2, 0.3])
axes2.plot(y, x, 'r->', lw=2)
axes2.set_title('Smaller Graph');

# %%
fig = plt.figure(figsize=(5, 4))

# the smaller graph is hidden by the larger graph
axes2 = fig.add_axes([0.2, 0.1, 0.2, 0.3])
axes2.plot(y, x, 'r->', lw=2)
axes2.set_title('Smaller Graph')

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes1.plot(x, y, 'b-o', lw=2)
axes1.set_title('Larger Graph');

# %%
fig = plt.figure(figsize=(5, 4))
# zorder is set so the smaller graph is visible
axes2 = fig.add_axes([0.2, 0.1, 0.2, 0.3])
axes2.plot(y, x, 'r->', lw=2)
axes2.set_title('Smaller Graph')
axes2.zorder = 2

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes1.plot(x, y, 'b-o', lw=2)
axes1.set_title('Larger Graph')
axes1.zorder = 1;

# %%
fig = plt.figure(figsize=(5, 4))

axes1 = fig.add_axes([0.1, 0.1, 0.4, 0.8])
axes1.plot(x, y, 'b-o', lw=2)
axes1.set_title('Left Graph')

axes2 = fig.add_axes([0.6, 0.1, 0.3, 0.8])
axes2.plot(x, y, 'r->', lw=4)
axes2.set_title('Right Graph');

# %% [markdown]
# ### `subplots()`
#
# - the `plt.subplots()` object will act as a more automatic axis manager

# %%
fig, axes = plt.subplots()

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
# Empty canvas of 1 by 3 subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

# %%
# axes is an array of axes to plot on
axes
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
axes[0]
# Out:
# <Axes: >

# %%
print(axes[0])
# Out:
# Axes(0.125,0.11;0.227941x0.77)

# %%
for index, ax in enumerate(axes):
    print(index, ax)
# Out:
# 0 Axes(0.125,0.11;0.227941x0.77)
# 1 Axes(0.398529,0.11;0.227941x0.77)
# 2 Axes(0.672059,0.11;0.227941x0.77)

# %%
fig

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

for index, ax in enumerate(axes):
    ax.plot(x, (index + 1) * x**2, 'm')
    ax.set_xlabel('x-label')
    ax.set_ylabel('y-label')
    ax.set_title('$f(x) = ' + str(index + 1) + 'x^2$')

axes[1].set_title("I have overidden the title of this ax!");

# %% [markdown]
# ### Saving Figures
#
# - Matplotlib can generate high-qaulity output in a number of formats:
#     - png
#     - jpg
#     - eps
#     - svg
#     - pgf
#     - pdf

# %%
# fig.savefig('filename.png')

# fig.savefig('filename.png', dpi=200)

# %% [markdown]
# #### Legends

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, x**2, 'r*', label='$f(x) = x^{2}$')
ax.plot(x, x**3, 'g--', label='$f(x) = x^{3}$')
ax.legend(loc=4);

# loc=0, best
# loc=1, top right
# loc=2, top left
# loc=3, bottom left
# loc=4, bottom right

# %% [markdown]
# ## 1.1.2.2 Doing More with Graphs to Model Data: Part 2

# %%
plt.style.use('classic')

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='Survived', hue='Pclass', data=titanic, palette='winter');

# %% [markdown]
# ### Histogram

# %%
plt.style.use('fivethirtyeight')

# %%
plt.figure(figsize=(8, 6))
sns.histplot(titanic['Age'],
             color='dodgerblue',
             edgecolor='lime',
             linewidth=3);

# %% [markdown]
# ### Boxplot

# %%
plt.style.use('Solarize_Light2')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Pclass', y='Age', data=titanic, palette='bright');

# %% [markdown]
# ## For the Quiz

# %%
mpg = sns.load_dataset('mpg')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.boxplot(x='origin', y='mpg', hue='cylinders', data=mpg);
